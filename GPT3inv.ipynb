# %% [markdown]
# <a href="https://colab.research.google.com/github/Jackil1993/GPT3_SCM/blob/main/GPT3inv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai

# %%
import os
import openai
from google.colab import drive
import openai
import pandas as pd

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
key_path = '/content/gdrive/My Drive/Data/GPT3_experiments/key.txt'
key = list(pd.read_csv(key_path).columns)[0]

# %%
key

# %%
openai.api_key = key

# %%
with open('/content/gdrive/My Drive/Data/GPT3_experiments/inventory.py', 'r') as file:
    code = file.read()
print(code)
# Out:
# # -*- coding: utf-8 -*-
# """inventory.ipynb
#
# Automatically generated by Colaboratory.
#
# Original file is located at
#     https://colab.research.google.com/drive/1V9m9pyiXz1ulJDgzcPaZvAkqaIAslFo_
# """
#
# from numpy import random
# import matplotlib.pyplot as plt
#
# time = 0 #days
# storage = 30
# lead = 6 #days
# r = 20 #reorder point
# Q = 30 #reorder quantity
# status = False #is order placed?
# next_delivery = float('inf')
# inv_hist = [storage]
# timings = [0]
#
# def generate_demand(average=5):
#   return round(random.exponential(average))
#
# def fulfill():
#   global time, storage
#   demand = generate_demand()
#   if demand <= storage:
#     storage -= demand
#     print('Day {}: {} items are sold'.format(time, demand))
#   else:
#     print('Day {}: {} items are sold. {} is lost in sales'.format(time, storage, demand-storage))
#     storage = 0
#
# def order():
#   global time, storage, lead, r, status, next_delivery
#   if storage <= r and status == False:
#     status = True
#     next_delivery = time + lead
#     print('Day {}: a new order is placed'.format(time))
#
# def delivery():
#   global time, storage, lead, Q, status, next_delivery
#   if status == True and next_delivery == time:
#     storage += Q
#     status = False
#     next_delivery = float('inf')
#     print('Day {}: {} items have been delivered'.format(time, Q))
#
# def advance_time():
#   global time, storage
#   time += 1
#   fulfill()
#   order()
#   delivery()
#   inv_hist.append(storage)
#   timings.append(time)
#
# while time < 31:
#   advance_time()
#
# plt.plot(timings, inv_hist, color='green', linewidth=2)
# plt.grid()
# plt.xlabel('time (days)')
# plt.ylabel('inventory level')
# plt.show()

# %%
def format_sentence(sentence) :
    sentenceSplit = filter(None, sentence.split("."))
    for s in sentenceSplit :
        print(s.strip() + ".")

# %%
pre = '# Python 3 \n'
end = '\n\n# Explanation of what the code does\n\n#'
prom = pre + code + end

# %%
response = openai.Completion.create(
  engine="davinci-codex",
  prompt=prom,
  temperature=0,
  max_tokens=64,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["#"]
)

# %%
description = response["choices"][0]["text"]

# %%
print('Short explanation ({} symbols):\n'.format(len(description)))
format_sentence(description)
# Out:
# Short explanation (272 symbols):
#
# The code above is a simulation of the inventory system.
# The code starts with a time of 0, and a storage of 30.
# The code then goes through a loop of 31 days.
# The code first checks if the demand is less than or equal to the storage.
# If it is, then the storage is subtracted.

# %%
longer_response = openai.Completion.create(
  engine="davinci-codex",
  prompt=prom,
  temperature=0,
  max_tokens=150,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["#"]
)

# %%
longer_description = longer_response["choices"][0]["text"]

# %%
print('Longer explanation ({} symbols):\n'.format(len(longer_description)))
format_sentence(longer_description)
# Out:
# Longer explanation (372 symbols):
#
# The code above is a simulation of the inventory system.
# The code starts with a time of 0, and a storage of 30.
# The lead time is 6 days, and the reorder point is 20.
# The reorder quantity is 30.
# The status is false, and the next delivery is infinity.
# The inventory history is a list that starts with the storage of 30.
# The timings is a list that starts with the time of 0.
# .

# %%
longest_response = openai.Completion.create(
  engine="davinci-codex",
  prompt=prom,
  temperature=0,
  max_tokens=250,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["#"]
)

# %%
longest_description = longest_response["choices"][0]["text"]

# %%
print('Full explanation ({} symbols):\n'.format(len(longest_description)))
format_sentence(longest_description)
# Out:
# Full explanation (362 symbols):
#
# The code above is a simulation of the inventory system.
# The code starts with a time of 0, and a storage of 30.
# The lead time is 6 days, and the reorder point is 20.
# The reorder quantity is 30.
# The status is false, and the next delivery is infinity.
# The inventory history is a list that starts with the storage of 30.
# The timings list starts with the time of 0.
# .

# %%
command = "\n\"\"\"\nThe time complexity of this function is"
prom2 = code + command
print(prom2)
# Out:
# # -*- coding: utf-8 -*-
# """inventory.ipynb
#
# Automatically generated by Colaboratory.
#
# Original file is located at
#     https://colab.research.google.com/drive/1V9m9pyiXz1ulJDgzcPaZvAkqaIAslFo_
# """
#
# from numpy import random
# import matplotlib.pyplot as plt
#
# time = 0 #days
# storage = 30
# lead = 6 #days
# r = 20 #reorder point
# Q = 30 #reorder quantity
# status = False #is order placed?
# next_delivery = float('inf')
# inv_hist = [storage]
# timings = [0]
#
# def generate_demand(average=5):
#   return round(random.exponential(average))
#
# def fulfill():
#   global time, storage
#   demand = generate_demand()
#   if demand <= storage:
#     storage -= demand
#     print('Day {}: {} items are sold'.format(time, demand))
#   else:
#     print('Day {}: {} items are sold. {} is lost in sales'.format(time, storage, demand-storage))
#     storage = 0
#
# def order():
#   global time, storage, lead, r, status, next_delivery
#   if storage <= r and status == False:
#     status = True
#     next_delivery = time + lead
#     print('Day {}: a new order is placed'.format(time))
#
# def delivery():
#   global time, storage, lead, Q, status, next_delivery
#   if status == True and next_delivery == time:
#     storage += Q
#     status = False
#     next_delivery = float('inf')
#     print('Day {}: {} items have been delivered'.format(time, Q))
#
# def advance_time():
#   global time, storage
#   time += 1
#   fulfill()
#   order()
#   delivery()
#   inv_hist.append(storage)
#   timings.append(time)
#
# while time < 31:
#   advance_time()
#
# plt.plot(timings, inv_hist, color='green', linewidth=2)
# plt.grid()
# plt.xlabel('time (days)')
# plt.ylabel('inventory level')
# plt.show()
# """
# The time complexity of this function is

# %%
complexity = openai.Completion.create(
  engine="davinci",
  prompt=prom2,
  temperature=0,
  max_tokens=64,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
  stop=["\n"]
)

# %%
estimated_complexity = complexity["choices"][0]["text"]

# %%
print('Complexity estimation:\n')
format_sentence(estimated_complexity)
# Out:
# Complexity estimation:
#
# O(n) where n is the number of days.
